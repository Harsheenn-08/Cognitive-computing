# %%
import numpy as np
import matplotlib.pyplot as plt
#1
gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]')
sum_all = np.sum(gfg)
sum_rows = np.sum(gfg, axis=1)
sum_cols = np.sum(gfg, axis=0)
print("Sum of all elements:", sum_all)
print("Sum of all elements row-wise:", sum_rows)
print("Sum of all elements column-wise:", sum_cols)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Sum of all elements: 45
# Sum of all elements row-wise: [[14]
#  [16]
#  [15]]
# Sum of all elements column-wise: [[20  9 16]]

# %%
#2
array = np.array([10, 52, 62, 16, 16, 54, 453])
sorted_array = np.sort(array)
sorted_indices = np.argsort(array)
smallest_4 = np.sort(array)[:4]
largest_5 = np.sort(array)[-5:]
print("Sorted array:", sorted_array)
print("Indices of sorted array:", sorted_indices)
print("4 smallest elements:", smallest_4)
print("5 largest elements:", largest_5)
# Out:
# Sorted array: [ 10  16  16  52  54  62 453]
# Indices of sorted array: [0 3 4 1 5 2 6]
# 4 smallest elements: [10 16 16 52]
# 5 largest elements: [ 16  52  54  62 453]

# %%
#2(b)
array_b = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0])
integer_elements = array_b[array_b == array_b.astype(int)]
float_elements = array_b[array_b != array_b.astype(int)]
print("Integer elements:", integer_elements)
print("Float elements:", float_elements)
# Out:
# Integer elements: [1. 2. 3. 2.]
# Float elements: [1.2 2.2]

# %%
#3
initials = "A B"  # Change this to your initials
X = sum(ord(c) for c in initials if c.isalpha())
sales = np.array([X, X+50, X+100, X+150, X+200])
tax_rate = ((X % 5) + 5) / 100
sales_after_tax = sales * (1 - tax_rate)
discounts = np.where(sales < X+100, 0.95, 0.90)
adjusted_sales = sales * discounts
sales_weeks = np.vstack([sales, sales * 1.02, sales * 1.04])
print("Sales values:", sales)
print("Sales after tax:", sales_after_tax)
print("Adjusted sales:", adjusted_sales)
print("Sales over weeks:", sales_weeks)
# Out:
# Sales values: [131 181 231 281 331]
# Sales after tax: [123.14 170.14 217.14 264.14 311.14]
# Adjusted sales: [124.45 171.95 207.9  252.9  297.9 ]
# Sales over weeks: [[131.   181.   231.   281.   331.  ]
#  [133.62 184.62 235.62 286.62 337.62]
#  [136.24 188.24 240.24 292.24 344.24]]

# %%
#4
x = np.linspace(-10, 10, 100)
y_x2 = x**2
y_sin = np.sin(x)
y_exp = np.exp(x)
y_log = np.log(np.abs(x) + 1)
plt.figure(figsize=(10, 6))
plt.plot(x, y_x2, label='y = x^2')
plt.plot(x, y_sin, label='y = sin(x)')
plt.plot(x, y_exp, label='y = e^x')
plt.plot(x, y_log, label='y = log(|x|+1)')
plt.xlabel('x values')
plt.ylabel('y values')
plt.title('Function Plots')
plt.legend()
plt.grid()
plt.show()
